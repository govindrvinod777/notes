# %% [markdown]
# <a href="https://colab.research.google.com/github/govindrvinod777/notes/blob/main/data_preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict = {"first score": [100,90,np.nan,95,np.nan],
        "second Score":[30,45,56,np.nan,np.nan],
        "third score":[np.nan,40,80,90,100],
        "fourth score":[np.nan,np.nan,np.nan,65,np.nan],
        "Fifth score":[12,15,19,43,54]}

df = pd.DataFrame(dict)
df.head()
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0           NaN         90.0          65.0           43
# 4          NaN           NaN        100.0           NaN           54

# %%
df.isna().sum()
# Out:
# first score     2
# second Score    2
# third score     1
# fourth score    4
# Fifth score     0
# dtype: int64

# %%
df1 = df.copy()
df1.fillna(40)
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0         40.0          40.0           12
# 1         90.0          45.0         40.0          40.0           15
# 2         40.0          56.0         80.0          40.0           19
# 3         95.0          40.0         90.0          65.0           43
# 4         40.0          40.0        100.0          40.0           54

# %%
df1.ffill()
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2         90.0          56.0         80.0           NaN           19
# 3         95.0          56.0         90.0          65.0           43
# 4         95.0          56.0        100.0          65.0           54

# %%
df1.fillna(method='ffill')
# Out:
# /tmp/ipython-input-598575452.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='ffill')
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2         90.0          56.0         80.0           NaN           19
# 3         95.0          56.0         90.0          65.0           43
# 4         95.0          56.0        100.0          65.0           54

# %%
df1.bfill()
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0         40.0          65.0           12
# 1         90.0          45.0         40.0          65.0           15
# 2         95.0          56.0         80.0          65.0           19
# 3         95.0           NaN         90.0          65.0           43
# 4          NaN           NaN        100.0           NaN           54

# %%
df1
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0           NaN         90.0          65.0           43
# 4          NaN           NaN        100.0           NaN           54

# %%
replace_vals = {"first score":10.1,"second Score" :30.2}
df1.fillna(replace_vals)
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2         10.1          56.0         80.0           NaN           19
# 3         95.0          30.2         90.0          65.0           43
# 4         10.1          30.2        100.0           NaN           54

# %%
df1.fillna(df1.mean())
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0     30.000000         77.5          65.0           12
# 1         90.0     45.000000         40.0          65.0           15
# 2         95.0     56.000000         80.0          65.0           19
# 3         95.0     43.666667         90.0          65.0           43
# 4         95.0     43.666667        100.0          65.0           54

# %%
df1.fillna(df1.median())
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0         85.0          65.0           12
# 1         90.0          45.0         40.0          65.0           15
# 2         95.0          56.0         80.0          65.0           19
# 3         95.0          45.0         90.0          65.0           43
# 4         95.0          45.0        100.0          65.0           54

# %%
df1['first score'].fillna(df1['Fifth score'])
# Out:
# 0    100.0
# 1     90.0
# 2     19.0
# 3     95.0
# 4     54.0
# Name: first score, dtype: float64

# %%
(df1['first score'].isna()) & (df1['Fifth score']>20)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df1.loc[df1['first score'].isna() & (df1['Fifth score']>20)]
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 4          NaN           NaN        100.0           NaN           54

# %%
df1.loc[df1['first score'].isna() & (df1['Fifth score']>20),'first score']=250

# %%
df1
# Out:
#    first score  second Score  third score  fourth score  Fifth score  \
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0           NaN         90.0          65.0           43
# 4        250.0           NaN        100.0           NaN           54
#
#    first Score
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4        250.0

# %%
df1.drop('first Score', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2696191036.py in <cell line: 0>()
# ----> 1 df1.drop('first Score', axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['first Score'] not found in axis"

# %%
df1
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0           NaN         90.0          65.0           43
# 4        250.0           NaN        100.0           NaN           54

# %%
df1.loc[df1['second Score'].isna() & (df1['fourth score']>20),'second Score']= 400

# %%
df1
# Out:
#    first score  second Score  third score  fourth score  Fifth score  \
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0         400.0         90.0          65.0           43
# 4        250.0           NaN        100.0           NaN           54
#
#    second score
# 0           NaN
# 1           NaN
# 2           NaN
# 3         400.0
# 4           NaN

# %%
df1.drop('second score', axis=1, inplace=True)

# %%
df1
# Out:
#    first score  second Score  third score  fourth score  Fifth score
# 0        100.0          30.0          NaN           NaN           12
# 1         90.0          45.0         40.0           NaN           15
# 2          NaN          56.0         80.0           NaN           19
# 3         95.0         400.0         90.0          65.0           43
# 4        250.0           NaN        100.0           NaN           54

# %%
hr = pd.read_csv("/content/hr_employees.csv")
hr.head()
# Out:
#    EmployeeID   Age Department   Salary  Experience  Education
# 0         101  29.0         IT  50000.0         5.0  Bachelors
# 1         102   NaN         HR  42000.0         3.0    Masters
# 2         103  35.0    Finance      NaN         NaN        NaN
# 3         104  42.0         IT  60000.0        10.0        PhD
# 4         105   NaN         HR  45000.0         2.0  Bachelors

# %%
hr
# Out:
#    EmployeeID   Age Department   Salary  Experience  Education
# 0         101  29.0         IT  50000.0         5.0  Bachelors
# 1         102   NaN         HR  42000.0         3.0    Masters
# 2         103  35.0    Finance      NaN         NaN        NaN
# 3         104  42.0         IT  60000.0        10.0        PhD
# 4         105   NaN         HR  45000.0         2.0  Bachelors

# %%
(hr['Age'].isna()) & (hr['Education']=='Bachelors')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
hr.loc[(hr['Age'].isna()) & (hr['Education']=='Bachelors'),'Age']=28

# %%
hr
# Out:
#    EmployeeID   Age Department   Salary  Experience  Education
# 0         101  29.0         IT  50000.0         5.0  Bachelors
# 1         102   NaN         HR  42000.0         3.0    Masters
# 2         103  35.0    Finance      NaN         NaN        NaN
# 3         104  42.0         IT  60000.0        10.0        PhD
# 4         105  28.0         HR  45000.0         2.0  Bachelors

# %%
hr['Salary'] = pd.to_numeric(hr['Salary'], errors='coerce')
hr.fillna({'Salary': hr['Salary'].mean()}, inplace=True)

# %%
hr
# Out:
#   EmployeeID   Age Department   Salary Experience  Education
# 0        101  29.0         IT  50000.0        5.0  Bachelors
# 1        102   Age         HR  42000.0        3.0    Masters
# 2        103  35.0    Finance  49250.0        Age        Age
# 3        104  42.0         IT  60000.0       10.0        PhD
# 4        105  28.0         HR  45000.0        2.0  Bachelors

# %%
hr['Age'] = pd.to_numeric(hr['Age'], errors='coerce')
hr.fillna({'Age': hr['Age'].median()}, inplace=True)

# %%
hr
# Out:
#   EmployeeID   Age Department   Salary Experience  Education
# 0        101  29.0         IT  50000.0        5.0  Bachelors
# 1        102  32.0         HR  42000.0        3.0    Masters
# 2        103  35.0    Finance  49250.0        Age        Age
# 3        104  42.0         IT  60000.0       10.0        PhD
# 4        105  28.0         HR  45000.0        2.0  Bachelors

# %%
(hr['Education'].isna()) & (hr['Education']=='Age')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Education, dtype: bool

# %%
hr.loc[hr['Education']=='Age', 'Education'] = 'phd'

# %%
hr
# Out:
#   EmployeeID   Age Department   Salary Experience  Education
# 0        101  29.0         IT  50000.0        5.0  Bachelors
# 1        102  32.0         HR  42000.0        3.0    Masters
# 2        103  35.0    Finance  49250.0        Age        phd
# 3        104  42.0         IT  60000.0       10.0        PhD
# 4        105  28.0         HR  45000.0        2.0  Bachelors

# %%
hr['Experience'] = pd.to_numeric(hr['Experience'], errors='coerce')

# %%
hr.fillna({'Experience': hr['Experience'].mean()}, inplace=True)

# %%
hr
# Out:
#   EmployeeID   Age Department   Salary  Experience  Education
# 0        101  29.0         IT  50000.0         5.0  Bachelors
# 1        102  32.0         HR  42000.0         3.0    Masters
# 2        103  35.0    Finance  49250.0         5.0        phd
# 3        104  42.0         IT  60000.0        10.0        PhD
# 4        105  28.0         HR  45000.0         2.0  Bachelors

# %%
beer = pd.read_csv("/content/beer-servings.csv")
beer.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
beer
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 7 columns]

# %%
num_cols = beer.select_dtypes(include='float64')
num_cols
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188            NaN            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 4 columns]

# %%
num_cols.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'beer_servings'}>,
#         <Axes: title={'center': 'spirit_servings'}>],
#        [<Axes: title={'center': 'wine_servings'}>,
#         <Axes: title={'center': 'total_litres_of_pure_alcohol'}>]],
#       dtype=object)

# %%
num_cols
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188            NaN            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 4 columns]

# %%
beer.fillna({'beer_servings': beer['beer_servings'].median()}, inplace=True)

# %%
beer.fillna({'spirit_servings': beer['spirit_servings'].median()}, inplace=True)

# %%
beer.fillna({'wine_servings': beer['wine_servings'].median()}, inplace=True)

# %%
beer.fillna({'total_litres_of_pure_alcohol': beer['total_litres_of_pure_alcohol'].median()}, inplace=True)

# %%
beer
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela           76.0            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 7 columns]

# %%
beer.isna().sum()
# Out:
# Unnamed: 0                      0
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
for i in num_cols:
    plt.figure(figsize=(10,5))
    plt.boxplot(beer[i])
    plt.title(i)

# %%
q1 = np.quantile(beer['spirit_servings'],0.25)
q3 = np.quantile(beer['spirit_servings'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 312.5
# -179.5
# 123.0

# %%
spirit_outliers = []
for i in beer['spirit_servings'] :
  if i > upper_bound or i < lower_bound :
    spirit_outliers.append(i)

# %%
spirit_outliers
# Out:
# [373.0, 438.0, 326.0, 326.0, 315.0]

# %%
beer['spirit_servings'] = beer['spirit_servings'].clip(lower=lower_bound,upper=upper_bound)

# %%
plt.boxplot(beer['spirit_servings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cbbd0644110>,
#   <matplotlib.lines.Line2D at 0x7cbbd0647c80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7cbbd0647230>,
#   <matplotlib.lines.Line2D at 0x7cbbd0647110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7cbbd057e720>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cbbd0645c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cbbd0647290>],
#  'means': []}

# %%
beer
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela           76.0            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 7 columns]

# %%
q1 = np.quantile(beer['wine_servings'],0.25)
q3 = np.quantile(beer['wine_servings'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 146.0
# -86.0
# 58.0

# %%
wine_outliers = []
for i in beer['wine_servings'] :
  if i > upper_bound or i < lower_bound :
    wine_outliers.append(i)

# %%
wine_outliers
# Out:
# [312.0,
#  221.0,
#  212.0,
#  191.0,
#  212.0,
#  172.0,
#  254.0,
#  278.0,
#  233.0,
#  370.0,
#  149.0,
#  175.0,
#  218.0,
#  185.0,
#  165.0,
#  237.0,
#  271.0,
#  190.0,
#  175.0,
#  339.0,
#  167.0,
#  276.0,
#  186.0,
#  280.0,
#  195.0,
#  220.0]

# %%
beer['wine_servings'] = beer['wine_servings'].clip(lower=lower_bound,upper=upper_bound)

# %%
plt.boxplot(beer['wine_servings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cbbd05863c0>,
#   <matplotlib.lines.Line2D at 0x7cbbd05866c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7cbbd0587e60>,
#   <matplotlib.lines.Line2D at 0x7cbbd0584140>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7cbbd0587020>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cbbd05843b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cbbd0584fe0>],
#  'means': []}

# %%
import seaborn as sns

# %%
titanic_df = sns.load_dataset("titanic")

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic_df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
titanic_df.drop("deck", axis=1, inplace=True)

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic_df.fillna({'age':titanic_df['age'].median()}, inplace=True)

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic_df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic_df['age'].hist(figsize=(10,10))
# Out:
# <Axes: >

# %%
titanic_df['embark_town'].hist(figsize=(10,10))
# Out:
# <Axes: >

# %%
for i in titanic_df:
    plt.figure(figsize=(10,5))
    plt.boxplot(titanic_df[i])
    plt.title(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2784327282.py in <cell line: 0>()
#       1 for i in titanic_df:
#       2     plt.figure(figsize=(10,5))
# ----> 3     plt.boxplot(titanic_df[i])
#       4     plt.title(i)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     293                 f"for the old name will be dropped in %(removal)s.")
#     294             kwargs[new] = kwargs.pop(old)
# --> 295         return func(*args, **kwargs)
#     296
#     297     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3075     data=None,
#    3076 ) -> dict[str, Any]:
# -> 3077     return gca().boxplot(
#    3078         x,
#    3079         notch=notch,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     293                 f"for the old name will be dropped in %(removal)s.")
#     294             kwargs[new] = kwargs.pop(old)
# --> 295         return func(*args, **kwargs)
#     296
#     297     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4108             bootstrap = mpl.rcParams['boxplot.bootstrap']
#    4109
# -> 4110         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4111                                        labels=tick_labels, autorange=autorange)
#    4112         if notch is None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1240
#    1241         # arithmetic mean
# -> 1242         stats['mean'] = np.mean(x)
#    1243
#    1244         # medians and quartiles
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3594             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3595
# -> 3596     return _methods._mean(a, axis=axis, dtype=dtype,
#    3597                           out=out, **kwargs)
#    3598
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     138             ret = ret.dtype.type(ret / rcount)
#     139     else:
# --> 140         ret = ret / rcount
#     141
#     142     return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
titanic_df['embarked']=titanic_df['embarked'].ffill()

# %%
titanic_df['embark_town']=titanic_df['embark_town'].ffill()

# %%
titanic_df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic_df = titanic_df.drop(['alive','class','alone','embarked','adult_male'],axis=1)

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  embark_town
# 0           0       3    male  22.0      1      0   7.2500    man  Southampton
# 1           1       1  female  38.0      1      0  71.2833  woman    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  woman  Southampton
# 3           1       1  female  35.0      1      0  53.1000  woman  Southampton
# 4           0       3    male  35.0      0      0   8.0500    man  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...    ...          ...
# 886         0       2    male  27.0      0      0  13.0000    man  Southampton
# 887         1       1  female  19.0      0      0  30.0000  woman  Southampton
# 888         0       3  female  28.0      1      2  23.4500  woman  Southampton
# 889         1       1    male  26.0      0      0  30.0000    man    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500    man   Queenstown
#
# [891 rows x 9 columns]

# %%
num_col = titanic_df.select_dtypes(include='float64')
num_col
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888  28.0  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
for i in num_col:
    plt.figure(figsize=(10,5))
    plt.boxplot(titanic_df[i])
    plt.title(i)

# %%
q1 = np.quantile(titanic_df['age'],0.25)
q3 = np.quantile(titanic_df['age'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 54.5
# 2.5
# 13.0

# %%
age_out = []
for i in titanic_df['age']:
  if i > upper_bound or i < lower_bound:
    age_out.append(i)

# %%
age_out
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
titanic_df['age']=titanic_df['age'].clip(lower=lower_bound,upper=upper_bound)

# %%
plt.boxplot(titanic_df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc265113710>,
#   <matplotlib.lines.Line2D at 0x7fc2681614c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc267fa5b20>,
#   <matplotlib.lines.Line2D at 0x7fc267fa4680>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc2647a8500>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc268646270>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc265ee3e60>],
#  'means': []}

# %%
q1 = np.quantile(titanic_df['fare'],0.25)
q3 = np.quantile(titanic_df['fare'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 65.6344
# -26.724
# 23.0896

# %%
fare_out = []
for i in titanic_df['fare']:
  if i > upper_bound or i < lower_bound:
    fare_out.append(i)

# %%
fare_out
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
#  512.3292,
#  78.85,
#  262.375,
#  71.0,
#  86.5,
#  120.0,
#  77.9583,
#  211.3375,
#  79.2,
#  69.55,
#  120.0,
#  93.5,
#  80.0,
#  83.1583,
#  69.55,
#  89.1042,
#  164.8667,
#  69.55,
#  83.1583]

# %%
titanic_df['fare']=titanic_df['fare'].clip(lower=lower_bound,upper=upper_bound)

# %%
plt.boxplot(titanic_df['fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc267fa2c00>,
#   <matplotlib.lines.Line2D at 0x7fc267fa06e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc2681ed400>,
#   <matplotlib.lines.Line2D at 0x7fc2681ef830>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc2686535c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc2681edd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc2681ef320>],
#  'means': []}

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  embark_town
# 0           0       3    male  22.0      1      0   7.2500    man  Southampton
# 1           1       1  female  38.0      1      0  65.6344  woman    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  woman  Southampton
# 3           1       1  female  35.0      1      0  53.1000  woman  Southampton
# 4           0       3    male  35.0      0      0   8.0500    man  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...    ...          ...
# 886         0       2    male  27.0      0      0  13.0000    man  Southampton
# 887         1       1  female  19.0      0      0  30.0000  woman  Southampton
# 888         0       3  female  28.0      1      2  23.4500  woman  Southampton
# 889         1       1    male  26.0      0      0  30.0000    man    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500    man   Queenstown
#
# [891 rows x 9 columns]

# %%
titanic_df.to_csv('clean titanic.csv')
