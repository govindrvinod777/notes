# %% [markdown]
# <a href="https://colab.research.google.com/github/govindrvinod777/notes/blob/main/sept10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pop = pd.read_csv("/content/population.csv")
pop
# Out:
#            country  population
# 0    United States  1278642419
# 1            China   792846414
# 2            India  1001406378
# 3            Japan  1206263687
# 4          Germany   428734972
# 5           Russia   420968276
# 6           Brazil   675094950
# 7   United Kingdom   674991378
# 8           France   434389014
# 9            Italy   254467210
# 10          Canada  1438267572
# 11       Australia   439285667
# 12     South Korea   618608295
# 13           Spain   898664919
# 14          Mexico   653061058
# 15       Indonesia    93409749
# 16          Turkey   247285876
# 17    Saudi Arabia   958477463
# 18       Argentina  1432830251
# 19    South Africa   916989541

# %%
import pandas as pd
gdp = pd.read_excel("/content/gdp.xlsx")
gdp
# Out:
#            Country             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %%
import pandas as pd
ius = pd.read_json("/content/internet_users.json")
ius
# Out:
#            country  internet_users
# 0    United States       745595490
# 1            China       685275917
# 2            India       606850704
# 3            Japan      1112451555
# 4          Germany       246827121
# 5           Russia       162156967
# 6           Brazil        24027075
# 7   United Kingdom       266047041
# 8           France       216417853
# 9            Italy        87191493
# 10          Canada       894102645
# 11       Australia       201619113
# 12     South Korea       291770691
# 13           Spain       794943861
# 14          Mexico       135489564
# 15       Indonesia         4584702
# 16          Turkey       128924625
# 17    Saudi Arabia       108944665
# 18       Argentina       421477197
# 19    South Africa       739194223

# %%
import pandas as pd
lit = pd.read_xml("/content/literacy_rate.xml")
lit
# Out:
#               name  literacy_rate
# 0    United States           72.7
# 1            China           82.2
# 2            India           80.3
# 3            Japan           97.5
# 4          Germany           92.9
# 5           Russia           89.1
# 6           Brazil           81.0
# 7   United Kingdom           82.9
# 8           France           97.6
# 9            Italy           83.7
# 10          Canada           70.8
# 11       Australia           71.6
# 12     South Korea           66.4
# 13           Spain           60.6
# 14          Mexico           76.5
# 15       Indonesia           75.4
# 16          Turkey           71.4
# 17    Saudi Arabia           60.5
# 18       Argentina           67.8
# 19    South Africa           87.7

# %%
pop.rename(columns={'country':'name'}, inplace=True)
pop
# Out:
#               name  population
# 0    United States  1278642419
# 1            China   792846414
# 2            India  1001406378
# 3            Japan  1206263687
# 4          Germany   428734972
# 5           Russia   420968276
# 6           Brazil   675094950
# 7   United Kingdom   674991378
# 8           France   434389014
# 9            Italy   254467210
# 10          Canada  1438267572
# 11       Australia   439285667
# 12     South Korea   618608295
# 13           Spain   898664919
# 14          Mexico   653061058
# 15       Indonesia    93409749
# 16          Turkey   247285876
# 17    Saudi Arabia   958477463
# 18       Argentina  1432830251
# 19    South Africa   916989541

# %%
gdp.rename(columns={'Country':'name'}, inplace=True)
gdp
# Out:
#               name             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %%
gdp.rename(columns={'Country':'name'}, inplace=True)
gdp
# Out:
#               name             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %%
ius.rename(columns={'country':'name'}, inplace=True)
ius
# Out:
#               name  internet_users
# 0    United States       745595490
# 1            China       685275917
# 2            India       606850704
# 3            Japan      1112451555
# 4          Germany       246827121
# 5           Russia       162156967
# 6           Brazil        24027075
# 7   United Kingdom       266047041
# 8           France       216417853
# 9            Italy        87191493
# 10          Canada       894102645
# 11       Australia       201619113
# 12     South Korea       291770691
# 13           Spain       794943861
# 14          Mexico       135489564
# 15       Indonesia         4584702
# 16          Turkey       128924625
# 17    Saudi Arabia       108944665
# 18       Argentina       421477197
# 19    South Africa       739194223

# %%
pop_gdp = pd.merge(pop,gdp, on='name', how='inner')
pop_gdp
# Out:
#               name  population             GDP
# 0    United States  1278642419  10450436373455
# 1            China   792846414   5086547998939
# 2            India  1001406378  14540718118693
# 3            Japan  1206263687  12473835857216
# 4          Germany   428734972   2038442396490
# 5           Russia   420968276  10987125474745
# 6           Brazil   675094950   8793052816619
# 7   United Kingdom   674991378  11799848684255
# 8           France   434389014   7758669752269
# 9            Italy   254467210  12907234326850
# 10          Canada  1438267572   8158351525190
# 11       Australia   439285667   5444267975247
# 12     South Korea   618608295   6562909541266
# 13           Spain   898664919  15275513099842
# 14          Mexico   653061058   2775281278756
# 15       Indonesia    93409749  12404144955318
# 16          Turkey   247285876   2581127745611
# 17    Saudi Arabia   958477463   8855399647233
# 18       Argentina  1432830251   8767336567320
# ...

# %%
pop_gdp_ius = pd.merge(pop_gdp,ius, on='name', how='inner')
pop_gdp_ius
# Out:
#               name  population             GDP  internet_users
# 0    United States  1278642419  10450436373455       745595490
# 1            China   792846414   5086547998939       685275917
# 2            India  1001406378  14540718118693       606850704
# 3            Japan  1206263687  12473835857216      1112451555
# 4          Germany   428734972   2038442396490       246827121
# 5           Russia   420968276  10987125474745       162156967
# 6           Brazil   675094950   8793052816619        24027075
# 7   United Kingdom   674991378  11799848684255       266047041
# 8           France   434389014   7758669752269       216417853
# 9            Italy   254467210  12907234326850        87191493
# 10          Canada  1438267572   8158351525190       894102645
# 11       Australia   439285667   5444267975247       201619113
# 12     South Korea   618608295   6562909541266       291770691
# 13           Spain   898664919  15275513099842       794943861
# ...

# %%
pop_gdp_ius_lit = pd.merge(pop_gdp_ius,lit, on='name', how='inner')
pop_gdp_ius_lit
# Out:
#               name  population             GDP  internet_users  literacy_rate
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
import pandas as pd


pop_gdp_ius_lit["internet_penetration_rate"] = (pop_gdp_ius_lit["internet_users"] / pop_gdp_ius_lit["population"] * 100)

pop_gdp_ius_lit
# Out:
#               name  population             GDP  internet_users  literacy_rate  \
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
high = pop_gdp_ius_lit.loc[pop_gdp_ius_lit['internet_penetration_rate'].idxmax()]
high
# Out:
# name                                  Japan
# population                       1206263687
# GDP                          12473835857216
# internet_users                   1112451555
# literacy_rate                          97.5
# internet_penetration_rate         92.222917
# Name: 3, dtype: object

# %%
avg = pop_gdp_ius_lit['literacy_rate'].mean()
print(avg)
# Out:
# 78.43

# %%
pop_gdp_ius_lit[['population','literacy_rate','internet_users']].corr()
# Out:
#                 population  literacy_rate  internet_users
# population        1.000000      -0.229585        0.749573
# literacy_rate    -0.229585       1.000000        0.074808
# internet_users    0.749573       0.074808        1.000000

# %%
import sqlite3

conn = sqlite3.connect("merge")
cursor = conn.cursor()
pop_gdp_ius_lit.to_sql(name='merge', con=conn, if_exists='replace', index=False)
# Out:
# 20

# %%
pd.read_sql_query('select * from merge',conn)
# Out:
#               name  population             GDP  internet_users  literacy_rate  \
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
pd.read_sql_query('select name , internet_penetration_rate from merge order by internet_penetration_rate desc limit 1',conn)
# Out:
#     name  internet_penetration_rate
# 0  Japan                  92.222917

# %%
pd.read_sql_query('select name,GDP/population AS per from merge',conn)
# Out:
#               name     per
# 0    United States    8173
# 1            China    6415
# 2            India   14520
# 3            Japan   10340
# 4          Germany    4754
# 5           Russia   26099
# 6           Brazil   13024
# 7   United Kingdom   17481
# 8           France   17861
# 9            Italy   50722
# 10          Canada    5672
# 11       Australia   12393
# 12     South Korea   10609
# 13           Spain   16998
# 14          Mexico    4249
# 15       Indonesia  132792
# 16          Turkey   10437
# 17    Saudi Arabia    9239
# 18       Argentina    6118
# 19    South Africa    3630

# %%
pd.read_sql_query('select name,GDP/population AS per from merge',conn)
# Out:
#               name     per
# 0    United States    8173
# 1            China    6415
# 2            India   14520
# 3            Japan   10340
# 4          Germany    4754
# 5           Russia   26099
# 6           Brazil   13024
# 7   United Kingdom   17481
# 8           France   17861
# 9            Italy   50722
# 10          Canada    5672
# 11       Australia   12393
# 12     South Korea   10609
# 13           Spain   16998
# 14          Mexico    4249
# 15       Indonesia  132792
# 16          Turkey   10437
# 17    Saudi Arabia    9239
# 18       Argentina    6118
# 19    South Africa    3630

# %%
pd.read_sql_query('select name,per from (select name ,GDP/population as per from merge) where per > 10000',conn)
# Out:
#               name     per
# 0            India   14520
# 1            Japan   10340
# 2           Russia   26099
# 3           Brazil   13024
# 4   United Kingdom   17481
# 5           France   17861
# 6            Italy   50722
# 7        Australia   12393
# 8      South Korea   10609
# 9            Spain   16998
# 10       Indonesia  132792
# 11          Turkey   10437

# %%
pd.read_sql_query('select sum(population) from merge',conn)
# Out:
#    sum(population)
# 0      14864685089
